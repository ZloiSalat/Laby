# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
file = 'GAZP_210701_220701.csv'
table = pd.read_csv(file)
print(table)
del table['<TIME>']
table.corr().round(3)
plt.show()
corr = table.corr()
plt.figure(figsize=(11,8))
sns.heatmap(corr, cmap="Greens",annot=True)
plt.show()
# Out:
#    <TICKER> <PER>    <DATE>  <TIME>  <OPEN>  <HIGH>   <LOW>  <CLOSE>  \
# 0      GAZP     M  20210701       0  281.88  298.48  273.10   287.35
# 1      GAZP     M  20210801       0  287.88  307.67  277.87   305.65
# 2      GAZP     M  20210901       0  306.60  364.53  306.19   360.80
# 3      GAZP     M  20211001       0  358.45  397.64  345.40   350.18
# 4      GAZP     M  20211101       0  350.30  360.00  310.62   334.24
# 5      GAZP     M  20211201       0  338.57  353.13  289.78   342.39
# 6      GAZP     M  20220101       0  345.01  358.10  280.60   334.80
# 7      GAZP     M  20220201       0  334.94  339.98  126.53   228.00
# 8      GAZP     M  20220301       0  251.41  278.90  206.00   242.48
# 9      GAZP     M  20220401       0  245.90  259.99  201.12   240.40
# 10     GAZP     M  20220501       0  241.01  305.00  227.22   293.75
# 11     GAZP     M  20220601       0  293.51  322.99  200.00   207.00
# 12     GAZP     M  20220701       0  200.84  205.78  181.20   195.26
#
#          <VOL>
# 0    938803890
# 1    945631030
# 2   1525970690
# 3   1592270650
# 4   1609001830
# 5   1614694140
# 6   2326513210
# 7   2515583630
# 8    333179180
# 9    644243080
# 10   673649490
# 11   899752640
# 12   840519840
